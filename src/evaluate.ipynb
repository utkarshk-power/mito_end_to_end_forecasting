# %%
import mlflow
import os
import pandas as pd
import joblib
import yaml
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from urllib.parse import urlparse
import logging
from dotenv import dotenv_values, load_dotenv

# %%
logging.basicConfig(level=logging.INFO)
os.chdir("/Users/urkarsh.kulshrestha/Documents/AI_environment/work_env/appletree_end_to_end_forecasting")
with open("./params.yaml", "rb") as file:
    params = yaml.safe_load(file)['evaluate']

# %%
def evaluate_model(data_path, feature_cols, target_col, model_path, test_size, random_state):
    data=pd.read_csv(data_path)
    x= data[feature_cols]
    y = data[target_col]
    split_idx = int((1 - test_size) * len(data))
    x_test = x.iloc[split_idx:]
    y_test = y.iloc[split_idx:]
    model = joblib.load(model_path)
    predictions = model.predict(x_test)
    test_mse = mean_squared_error(y_test, predictions)
    test_mae = mean_absolute_error(y_test, predictions)
    test_r2 = r2_score(y_test, predictions)
    logging.info("Test Metrics: MSE=%.4f, MAE=%.4f, R2=%.4f", test_mse, test_mae, test_r2)


    with mlflow.start_run():
        mlflow.log_metrics({
            "test_mse": test_mse,
            "test_mae": test_mae,
            "test_r2": test_r2
        })
        mlflow.set_tag("model", "XGBoostRegressor")
        mlflow.set_tag("model_stage", "evaluate")
        mlflow.set_tag("Test Data Split", "15 %")
        mlflow.set_tag("Developer", "Utkarsh Kulshrestha")
        mlflow.set_tag("Data Used", "Mito Data March,2025-January,2026")

# %%
if __name__ == "__main__":
    load_dotenv("/Users/urkarsh.kulshrestha/Documents/AI_environment/work_env/appletree_end_to_end_forecasting/.env")
    mlflow.set_tracking_uri(os.environ.get("MLFLOW_TRACKING_URI"))
    mlflow.set_experiment("Mito Load Forecasting with MLOps Principles")
    evaluate_model(params['data'], 
                   params['feature_cols'], 
                   params['target'], 
                   params['model_path'], 
                   params['test_size'], 
                   params['random_state'])
# Out:
# WARNING:dotenv.main:python-dotenv could not parse statement starting at line 1
# INFO:root:Test Metrics: MSE=43.5014, MAE=3.1889, R2=0.9331
# WARNING:urllib3.connectionpool:Retrying (Retry(total=6, connect=7, read=6, redirect=7, status=7)) after connection broken by 'ProtocolError('Remote end closed connection without response')': /utkarshk-power/mito_end_to_end_forecasting.mlflow/api/2.0/mlflow/runs/get?run_uuid=1ea2576ec3b049d58bec378aaaf31802&run_id=1ea2576ec3b049d58bec378aaaf31802
# 🏃 View run shivering-pig-931 at: https://dagshub.com/utkarshk-power/mito_end_to_end_forecasting.mlflow/#/experiments/1/runs/1ea2576ec3b049d58bec378aaaf31802
# 🧪 View experiment at: https://dagshub.com/utkarshk-power/mito_end_to_end_forecasting.mlflow/#/experiments/1
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[31], line 5
#       3 mlflow.set_tracking_uri(os.environ.get("MLFLOW_TRACKING_URI"))
#       4 mlflow.set_experiment("Mito Load Forecasting with MLOps Principles")
# ----> 5 evaluate_model(params['data'],
#       6                params['feature_cols'],
#       7                params['target'],
#       8                params['model_path'],
#       9                params['test_size'],
#      10                params['random_state'])
#
# Cell In[30], line 15, in evaluate_model(data_path, feature_cols, target_col, model_path, test_size, random_state)
#      12 test_r2 = r2_score(y_test, predictions)
#      13 logging.info("Test Metrics: MSE=%.4f, MAE=%.4f, R2=%.4f", test_mse, test_mae, test_r2)
# ---> 15 mlflow.end_run()
#      16 with mlflow.start_run():
#      17     mlflow.log_metrics({
#      18         "test_mse": test_mse,
#      19         "test_mae": test_mae,
#      20         "test_r2": test_r2
#      21     })
#
# File ~/Documents/AI_environment/work_env/appletree_end_to_end_forecasting/appletree_mlops_env/lib/python3.14/site-packages/mlflow/tracking/fluent.py:628, in end_run(status)
#     626 last_active_run_id = run.info.run_id
#     627 _last_active_run_id.set(last_active_run_id)
# --> 628 MlflowClient().set_terminated(last_active_run_id, status)
#     629 if last_active_run_id in run_id_to_system_metrics_monitor:
#     630     system_metrics_monitor = run_id_to_system_metrics_monitor.pop(last_active_run_id)
#
# File ~/Documents/AI_environment/work_env/appletree_end_to_end_forecasting/appletree_mlops_env/lib/python3.14/site-packages/mlflow/tracking/client.py:3624, in MlflowClient.set_terminated(self, run_id, status, end_time)
#    3579 def set_terminated(
#    3580     self, run_id: str, status: str | None = None, end_time: int | None = None
#    3581 ) -> None:
#    3582     """Set a run's status to terminated.
#    3583
#    3584     Args:
#    (...)   3622
#    3623     """
# -> 3624     self._tracking_client.set_terminated(run_id, status, end_time)
#
# File ~/Documents/AI_environment/work_env/appletree_end_to_end_forecasting/appletree_mlops_env/lib/python3.14/site-packages/mlflow/tracking/_tracking_service/client.py:797, in TrackingServiceClient.set_terminated(self, run_id, status, end_time)
#     795 self.store.shut_down_async_logging()
#     796 self._log_url(run_id)
# --> 797 self.store.update_run_info(
#     798     run_id,
#     799     run_status=RunStatus.from_string(status),
#     800     end_time=end_time,
#     801     run_name=None,
#     802 )
#
# File ~/Documents/AI_environment/work_env/appletree_end_to_end_forecasting/appletree_mlops_env/lib/python3.14/site-packages/mlflow/store/tracking/rest_store.py:330, in RestStore.update_run_info(self, run_id, run_status, end_time, run_name)
#     320 """Updates the metadata of the specified run."""
#     321 req_body = message_to_json(
#     322     UpdateRun(
#     323         run_uuid=run_id,
#    (...)    328     )
#     329 )
# --> 330 response_proto = self._call_endpoint(UpdateRun, req_body)
#     331 return RunInfo.from_proto(response_proto.run_info)
#
# File ~/Documents/AI_environment/work_env/appletree_end_to_end_forecasting/appletree_mlops_env/lib/python3.14/site-packages/mlflow/store/tracking/rest_store.py:222, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds, response_proto)
#     220     endpoint, method = method_to_info[api]
#     221 response_proto = response_proto or api.Response()
# --> 222 return call_endpoint(
#     223     self.get_host_creds(),
#     224     endpoint,
#     225     method,
#     226     json_body,
#     227     response_proto,
#     228     retry_timeout_seconds=retry_timeout_seconds,
#     229 )
#
# File ~/Documents/AI_environment/work_env/appletree_end_to_end_forecasting/appletree_mlops_env/lib/python3.14/site-packages/mlflow/utils/rest_utils.py:596, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     593     call_kwargs["json"] = json_body
#     594     response = http_request(**call_kwargs)
# --> 596 response = verify_rest_response(response, endpoint)
#     597 response_to_parse = response.text
#     598 try:
#
# File ~/Documents/AI_environment/work_env/appletree_end_to_end_forecasting/appletree_mlops_env/lib/python3.14/site-packages/mlflow/utils/rest_utils.py:315, in verify_rest_response(response, endpoint)
#     313 if response.status_code != 200:
#     314     if _can_parse_as_json_object(response.text):
# --> 315         raise RestException(json.loads(response.text))
#     316     else:
#     317         base_msg = (
#     318             f"API request to endpoint {endpoint} "
#     319             f"failed with error code {response.status_code} != 200"
#     320         )
#
# RestException: INVALID_PARAMETER_VALUE: Response: {'error_code': 'INVALID_PARAMETER_VALUE'}
